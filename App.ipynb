# %%
# !unzip /content/Deep_Learning_for_Image_Analysis.zip
# Out:
# Archive:  /content/Deep_Learning_for_Image_Analysis.zip
#    creating: Deep_Learning_for_Image_Analysis/
#    creating: Deep_Learning_for_Image_Analysis/Model/
#   inflating: Deep_Learning_for_Image_Analysis/Model/loss.py
#   inflating: Deep_Learning_for_Image_Analysis/Model/metrics.py
#   inflating: Deep_Learning_for_Image_Analysis/Model/model.py
#   inflating: Deep_Learning_for_Image_Analysis/requirements.txt
#   inflating: Deep_Learning_for_Image_Analysis/setup.sh
#   inflating: Deep_Learning_for_Image_Analysis/train.py
#    creating: Deep_Learning_for_Image_Analysis/Utils/
#   inflating: Deep_Learning_for_Image_Analysis/Utils/categories.py
#   inflating: Deep_Learning_for_Image_Analysis/Utils/config.py
#   inflating: Deep_Learning_for_Image_Analysis/Utils/data_loader.py
#   inflating: Deep_Learning_for_Image_Analysis/Utils/downloader.py
#   inflating: Deep_Learning_for_Image_Analysis/Utils/inference.py
#   inflating: Deep_Learning_for_Image_Analysis/Utils/utils.py
#    creating: Deep_Learning_for_Image_Analysis/Utils/__pycache__/
#   inflating: Deep_Learning_for_Image_Analysis/Utils/__pycache__/categories.cpython-312.pyc
#   inflating: Deep_Learning_for_Image_Analysis/Utils/__pycache__/data_loader.cpython-312.pyc
#   inflating: Deep_Learning_for_Image_Analysis/Utils/__pycache__/utils.cpython-312.pyc

# %% [markdown]
# # Download COCO-2017 dataset

# %%
# !python /content/Deep_Learning_for_Image_Analysis/Utils/downloader.py
# Out:
# Downloading annotations...
# Downloading http://images.cocodataset.org/annotations/annotations_trainval2017.zip to /content/input/annotations_trainval2017.zip
# annotations_trainval2017.zip: 100% 241M/241M [00:02<00:00, 101MiB/s]
# Finished downloading http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Extracting /content/input/annotations_trainval2017.zip to /content/input
# Finished extracting /content/input/annotations_trainval2017.zip
# Removed /content/input/annotations_trainval2017.zip
# Annotations download complete.
# Downloading image info...
# Downloading http://images.cocodataset.org/annotations/image_info_test2017.zip to /content/input/image_info_test2017.zip
# image_info_test2017.zip: 100% 1.09M/1.09M [00:00<00:00, 7.03MiB/s]
# Finished downloading http://images.cocodataset.org/annotations/image_info_test2017.zip
# Extracting /content/input/image_info_test2017.zip to /content/input
# Finished extracting /content/input/image_info_test2017.zip
# Removed /content/input/image_info_test2017.zip
# Image info download complete.
# Downloading train data...
# Downloading http://images.cocodataset.org/zips/train2017.zip to /content/input/train2017.zip
# train2017.zip: 100% 18.0G/18.0G [03:16<00:00, 98.3MiB/s]
# Finished downloading http://images.cocodataset.org/zips/train2017.zip
# Extracting /content/input/train2017.zip to /content/input
# Finished extracting /content/input/train2017.zip
# Removed /content/input/train2017.zip
# Train data download complete.
# Downloading validation data...
# Downloading http://images.cocodataset.org/zips/val2017.zip to /content/input/val2017.zip
# val2017.zip: 100% 778M/778M [00:08<00:00, 98.7MiB/s]
# Finished downloading http://images.cocodataset.org/zips/val2017.zip
# Extracting /content/input/val2017.zip to /content/input
# Finished extracting /content/input/val2017.zip
# Removed /content/input/val2017.zip
# Validation data download complete.
# Downloading test data...
# Downloading http://images.cocodataset.org/zips/test2017.zip to /content/input/test2017.zip
# test2017.zip: 100% 6.19G/6.19G [01:19<00:00, 83.8MiB/s]
# Finished downloading http://images.cocodataset.org/zips/test2017.zip
# Extracting /content/input/test2017.zip to /content/input
# Finished extracting /content/input/test2017.zip
# Removed /content/input/test2017.zip
# Test data download complete.
# Contents of input directory:
# train2017
# test2017
# val2017
# annotations

# %% [markdown]
# # Install Requirements

# %%
# !pip install -r /content/Deep_Learning_for_Image_Analysis/requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 2)) (0.21.0+cu124)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 6)) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 7)) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 9)) (4.23.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 10)) (1.14.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from -r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (0.19.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 2)) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 6)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 6)) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 6)) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 6)) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 8)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 8)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 8)) (3.2.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 9)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 9)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 9)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 9)) (0.24.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (2.11.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (2.26.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r /content/Deep_Learning_for_Image_Analysis/requirements.txt (line 11)) (5.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 99.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# # Run Train.py

# %%
# !python /content/Deep_Learning_for_Image_Analysis/train.py
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: anndischeh (anndischeh-univ-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250427_091428-frc5pclm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run yolo-v1
# wandb: ⭐️ View project at https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20image%20Analysis
# wandb: 🚀 View run at https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20image%20Analysis/runs/frc5pclm
# Figure(1000x800)
# /content/working/weights/
# Error: Model file not found at /content/working/weights/YOLOv1_3.pt.  Starting from scratch.
# EPOCH: 1/35
#
# Training: 100% 541/541 [13:50<00:00,  1.54s/it, loss:8.605797]
# Time spent loading data: 372.01s, time spent training: 44.39s (0.89/0.11)
# Evaluating: 100% 23/23 [00:21<00:00,  1.06it/s]
#
# mAP: 0.35, Average loss: 7.359381, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 2/35
#
# Training: 100% 541/541 [13:34<00:00,  1.51s/it, loss:8.032851]
# Time spent loading data: 363.65s, time spent training: 43.95s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.01, Average loss: 8.516938, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 3/35
#
# Training: 100% 541/541 [13:33<00:00,  1.50s/it, loss:8.624245]
# Time spent loading data: 363.07s, time spent training: 43.93s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.04, Average loss: 8.573411, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 4/35
#
# Training: 100% 541/541 [13:33<00:00,  1.50s/it, loss:12.564015]
# Time spent loading data: 363.70s, time spent training: 43.98s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.04, Average loss: 11.642813, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 5/35
#
# Training: 100% 541/541 [13:32<00:00,  1.50s/it, loss:7.105030]
# Time spent loading data: 363.52s, time spent training: 43.97s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.00, Average loss: 6.183044, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 6/35
#
# Training: 100% 541/541 [13:44<00:00,  1.52s/it, loss:5.317306]
# Time spent loading data: 368.72s, time spent training: 44.06s (0.89/0.11)
# Evaluating: 100% 23/23 [00:19<00:00,  1.16it/s]
#
# mAP: 0.00, Average loss: 6.176329, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 7/35
#
# Training: 100% 541/541 [13:40<00:00,  1.52s/it, loss:5.570904]
# Time spent loading data: 366.80s, time spent training: 44.04s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.03, Average loss: 5.993826, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 8/35
#
# Training: 100% 541/541 [13:33<00:00,  1.50s/it, loss:6.781155]
# Time spent loading data: 364.51s, time spent training: 43.97s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.07, Average loss: 5.904308, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 9/35
#
# Training: 100% 541/541 [13:34<00:00,  1.50s/it, loss:6.199078]
# Time spent loading data: 363.65s, time spent training: 44.02s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.03, Average loss: 5.816596, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 10/35
#
# Training: 100% 541/541 [13:32<00:00,  1.50s/it, loss:5.814682]
# Time spent loading data: 363.06s, time spent training: 44.04s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.01, Average loss: 5.793883, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 11/35
#
# Training: 100% 541/541 [13:38<00:00,  1.51s/it, loss:4.518380]
# Time spent loading data: 365.75s, time spent training: 44.05s (0.89/0.11)
# Evaluating: 100% 23/23 [00:20<00:00,  1.15it/s]
#
# mAP: 0.02, Average loss: 5.803586, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 12/35
#
# Training: 100% 541/541 [13:46<00:00,  1.53s/it, loss:6.082956]
# Time spent loading data: 370.22s, time spent training: 44.08s (0.89/0.11)
# Evaluating: 100% 23/23 [00:21<00:00,  1.05it/s]
#
# mAP: 0.02, Average loss: 5.790245, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 13/35
#
# Training: 100% 541/541 [13:31<00:00,  1.50s/it, loss:6.678901]
# Time spent loading data: 363.05s, time spent training: 43.89s (0.89/0.11)
# Evaluating: 100% 23/23 [00:22<00:00,  1.00it/s]
#
# mAP: 0.02, Average loss: 5.778143, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 14/35
#
# Training: 100% 541/541 [13:36<00:00,  1.51s/it, loss:5.691606]
# Time spent loading data: 364.62s, time spent training: 44.04s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.02, Average loss: 5.798940, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 15/35
#
# Training: 100% 541/541 [13:38<00:00,  1.51s/it, loss:5.635037]
# Time spent loading data: 365.98s, time spent training: 44.02s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.03s/it]
#
# mAP: 0.01, Average loss: 5.773668, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 16/35
#
# Training: 100% 541/541 [13:44<00:00,  1.52s/it, loss:5.702948]
# Time spent loading data: 367.96s, time spent training: 44.12s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.02, Average loss: 5.775287, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 17/35
#
# Training: 100% 541/541 [13:47<00:00,  1.53s/it, loss:4.916804]
# Time spent loading data: 369.46s, time spent training: 44.09s (0.89/0.11)
# Evaluating: 100% 23/23 [00:20<00:00,  1.14it/s]
#
# mAP: 0.02, Average loss: 5.776496, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 18/35
#
# Training: 100% 541/541 [13:24<00:00,  1.49s/it, loss:5.153054]
# Time spent loading data: 358.92s, time spent training: 43.90s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.02, Average loss: 5.769877, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 19/35
#
# Training: 100% 541/541 [13:37<00:00,  1.51s/it, loss:5.136311]
# Time spent loading data: 365.64s, time spent training: 44.00s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.02s/it]
#
# mAP: 0.02, Average loss: 5.786659, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 20/35
#
# Training: 100% 541/541 [13:52<00:00,  1.54s/it, loss:5.800041]
# Time spent loading data: 373.18s, time spent training: 44.19s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.04s/it]
#
# mAP: 0.01, Average loss: 5.780178, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 21/35
#
# Training: 100% 541/541 [13:49<00:00,  1.53s/it, loss:5.610369]
# Time spent loading data: 371.38s, time spent training: 44.16s (0.89/0.11)
# Evaluating: 100% 23/23 [00:19<00:00,  1.16it/s]
#
# mAP: 0.01, Average loss: 5.767985, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 22/35
#
# Training: 100% 541/541 [13:51<00:00,  1.54s/it, loss:6.072357]
# Time spent loading data: 371.63s, time spent training: 44.13s (0.89/0.11)
# Evaluating: 100% 23/23 [00:22<00:00,  1.05it/s]
#
# mAP: 0.02, Average loss: 5.772418, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 23/35
#
# Training: 100% 541/541 [13:40<00:00,  1.52s/it, loss:6.196851]
# Time spent loading data: 366.87s, time spent training: 44.07s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.01, Average loss: 5.779379, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 24/35
#
# Training: 100% 541/541 [13:35<00:00,  1.51s/it, loss:5.647388]
# Time spent loading data: 364.37s, time spent training: 44.04s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.02s/it]
#
# mAP: 0.01, Average loss: 5.785472, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 25/35
#
# Training: 100% 541/541 [13:36<00:00,  1.51s/it, loss:4.938255]
# Time spent loading data: 365.40s, time spent training: 43.96s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.01s/it]
#
# mAP: 0.02, Average loss: 5.781585, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 26/35
#
# Training: 100% 541/541 [13:32<00:00,  1.50s/it, loss:5.497516]
# Time spent loading data: 362.64s, time spent training: 43.97s (0.89/0.11)
# Evaluating: 100% 23/23 [00:22<00:00,  1.00it/s]
#
# mAP: 0.02, Average loss: 5.776851, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 27/35
#
# Training: 100% 541/541 [13:40<00:00,  1.52s/it, loss:5.095514]
# Time spent loading data: 366.83s, time spent training: 44.03s (0.89/0.11)
# Evaluating: 100% 23/23 [00:20<00:00,  1.15it/s]
#
# mAP: 0.02, Average loss: 5.783004, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 28/35
#
# Training: 100% 541/541 [13:53<00:00,  1.54s/it, loss:5.809335]
# Time spent loading data: 374.14s, time spent training: 44.11s (0.89/0.11)
# Evaluating: 100% 23/23 [00:21<00:00,  1.06it/s]
#
# mAP: 0.02, Average loss: 5.767382, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 29/35
#
# Training: 100% 541/541 [13:43<00:00,  1.52s/it, loss:5.990861]
# Time spent loading data: 368.64s, time spent training: 44.01s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.02s/it]
#
# mAP: 0.02, Average loss: 5.779286, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 30/35
#
# Training: 100% 541/541 [13:35<00:00,  1.51s/it, loss:6.025271]
# Time spent loading data: 364.51s, time spent training: 44.03s (0.89/0.11)
# Evaluating: 100% 23/23 [00:22<00:00,  1.00it/s]
#
# mAP: 0.01, Average loss: 5.771053, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 31/35
#
# Training: 100% 541/541 [13:30<00:00,  1.50s/it, loss:5.726918]
# Time spent loading data: 362.13s, time spent training: 43.95s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.00s/it]
#
# mAP: 0.02, Average loss: 5.770463, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 32/35
#
# Training: 100% 541/541 [13:38<00:00,  1.51s/it, loss:6.759771]
# Time spent loading data: 366.37s, time spent training: 44.01s (0.89/0.11)
# Evaluating: 100% 23/23 [00:23<00:00,  1.03s/it]
#
# mAP: 0.02, Average loss: 5.776596, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 33/35
#
# Training: 100% 541/541 [13:44<00:00,  1.52s/it, loss:5.796717]
# Time spent loading data: 368.45s, time spent training: 44.14s (0.89/0.11)
# Evaluating: 100% 23/23 [00:22<00:00,  1.01it/s]
#
# mAP: 0.01, Average loss: 5.777045, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 34/35
#
# Training: 100% 541/541 [13:49<00:00,  1.53s/it, loss:5.307636]
# Time spent loading data: 371.40s, time spent training: 44.11s (0.89/0.11)
# Evaluating: 100% 23/23 [00:20<00:00,  1.14it/s]
#
# mAP: 0.02, Average loss: 5.787908, 2933 images tested
# /content/working/weights/
# Model saved to /content/working/weights/YOLOv1_3.pt
# EPOCH: 35/35
#
# Training:  93% 505/541 [12:39<00:55,  1.54s/it, loss:5.379542]
